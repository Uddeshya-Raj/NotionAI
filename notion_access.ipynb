# %%
import os
from notion_client import Client
from notion_client.errors import HTTPResponseError
import json
import time

# %%
curr_dir = os.getcwd()
token_file = os.path.join(curr_dir, 'notion_integration_token.txt')
with open(token_file, 'r') as file:
    notion_integration_token = file.read().strip()

# %%
notion = Client(auth=notion_integration_token)

# %%
def get_primary_pages_list():
    """Retrieve the list of sources from the Notion database whose parent is the workspace."""
    results = []
    next_cursor = None
    while True:
        response = notion.search(page_size=100, start_cursor=next_cursor)
        # Filter for items whose parent.type is 'workspace'
        workspace_items = [
            item.get('id', '') for item in response['results']
            if item.get('parent', {}).get('type') == 'workspace'
        ]
        results.extend(workspace_items)
        next_cursor = response.get('next_cursor')
        if not next_cursor:
            break
    return results

# %%
pages = get_primary_pages_list()
print(pages)
# Out:
# ['2184ba0f-0a3c-8034-bc0b-e4c46063376b', '2184ba0f-0a3c-8075-99cf-f77bd6684f86', '2184ba0f-0a3c-8012-88cc-d7f9c05c3490', '2184ba0f-0a3c-803d-b276-c4bcd0551664']

# %%
def show_children(
    block_id, 
    # result=None,
    retries=3, 
    delay=1
    ):
    # if result is None:
    #     result = []

    try:
        block_type = notion.blocks.retrieve(block_id=block_id)['type']
        if block_type == 'unsupported':
            return

        children = notion.blocks.children.list(block_id=block_id)['results']
        for child in children:
            # Only append if not a database without a title
            if not (
                (child.get('type') == 'child_database' and not child['child_database'].get('title', '')) or
                (child.get('type') == 'database' and not child.get('title', ''))
            ):
                print(json.dumps(child, indent=4))
                # result.append(child)
            if child.get('has_children'):
                show_children(child['id'])
    except HTTPResponseError as e:
        if retries > 0:
            print(f"Retrying due to error: {e}. Retries left: {retries}")
            time.sleep(delay)
            show_children(block_id, retries - 1, delay * 2)  # Exponential backoff
        else:
            print(f"Failed after retries. Skipping block {block_id}. Error: {e}")

    # return result

# %%
import time
import logging
from notion_client.errors import HTTPResponseError

def get_children_blocks(block_id, notion, max_retries=3, delay=1):
    """
    A page is also a block in Notion.
    Recursively retrieves all child blocks for a given Notion block ID.
    Returns a flat list of blocks. Raises an exception if retrieval fails.
    """
    result = []
    try:
        # Retrieve the block type (optional, can skip if not needed)
        block_type = notion.blocks.retrieve(block_id=block_id)['type']
        if block_type == 'unsupported':
            return result

        # Pagination handling
        next_cursor = None
        while True:
            response = notion.blocks.children.list(block_id=block_id, start_cursor=next_cursor)
            children = response['results']
            for child in children:
                if child.get('type') == 'unsupported':
                    continue
                # Skip databases without a title
                if not (
                    (child.get('type') == 'child_database' and not child['child_database'].get('title', '')) or
                    (child.get('type') == 'database' and not child.get('title', ''))
                ):
                    result.append(child)
                if child.get('has_children'):
                    # Recursively get children and extend the result
                    result.extend(get_children_blocks(child['id'], notion, max_retries, delay))
            next_cursor = response.get('next_cursor')
            if not next_cursor:
                break
    except HTTPResponseError as e:
        if max_retries > 0:
            logging.warning(f"Retrying due to error: {e}. Retries left: {max_retries}")
            time.sleep(delay)
            return get_children_blocks(block_id, notion, max_retries - 1, delay * 2)
        else:
            logging.error(f"Failed after retries. Skipping block {block_id}. Error: {e}")
            raise Exception(f"Failed after retries. Skipping block {block_id}. Error: {e}")

    return result

# %%
def extract_table_as_markdown(table_block_id):
    table_rows = notion.blocks.children.list(block_id=table_block_id)['results']
    table_data = []
    for row in table_rows:
        cells = row['table_row']['cells']
        row_text = [
            ''.join(cell_obj.get('plain_text', '') for cell_obj in cell)
            for cell in cells
        ]
        table_data.append(row_text)
    
    # Step 2: Compute the max width for each column
    num_cols = max(len(row) for row in table_data)
    col_widths = [0] * num_cols
    for row in table_data:
        for idx, cell in enumerate(row):
            col_widths[idx] = max(col_widths[idx], len(cell))
    
    # Step 3: Pad each cell to column width
    def pad(cell, width):
        return cell + ' ' * (width - len(cell))
    
    padded_table = []
    for row in table_data:
        padded_row = [pad(cell, col_widths[idx]) for idx, cell in enumerate(row)]
        padded_table.append(padded_row)
    
    # Step 4: Build Markdown lines
    lines = []
    # Header
    lines.append('| ' + ' | '.join(padded_table[0]) + ' |')
    # Separator
    lines.append('|' + '|'.join(['-' * (w + 2) for w in col_widths]) + '|')
    # Data rows
    for row in padded_table[1:]:
        lines.append('| ' + ' | '.join(row) + ' |')
    return '\n'.join(lines)

# %%
def extract_simple_content(info):
    # info = notion.blocks.retrieve(block_id=block_id)
    content = ''
    block_type = info['type']

    # Equation block
    if block_type == 'equation':
        content += info['equation'].get('expression', '')

    # Table block
    elif block_type == 'table':
        table_content = extract_table_as_markdown(info.get('id', ''))
        content += table_content

    # To-do block
    elif block_type == 'to_do':
        to_do = info['to_do']
        # Extract text from rich_text
        text_content = ''.join(
            t['text']['content']
            for t in to_do.get('rich_text', [])
            if 'text' in t and 'content' in t['text']
        )
        content += text_content
        if to_do.get('checked', False):
            content += ' (done)'

    # Blocks with rich_text (paragraph, heading, etc.)
    elif "rich_text" in info.get(block_type, {}):
        rich_text = info[block_type]['rich_text']
        for text in rich_text:
            if 'text' in text and 'content' in text['text']:
                text_content = text['text']['content']
                content += text_content
            elif 'equation' in text and 'expression' in text['equation']:
                equation_content = text['equation']['expression']
                content += equation_content

    return content

# %%
def extract_property_value(prop):
    """Extracts the display value from a Notion property dict."""
    prop_type = prop.get('type')
    if prop_type == 'title':
        # Title is a list of rich_text objects
        return ''.join([t.get('plain_text', '') for t in prop['title']])
    elif prop_type == 'rich_text':
        return ''.join([t.get('plain_text', '') for t in prop['rich_text']])
    elif prop_type == 'select':
        return prop['select']['name'] if prop['select'] else ''
    elif prop_type == 'multi_select':
        return ', '.join([item['name'] for item in prop['multi_select']])
    elif prop_type == 'checkbox':
        return 'Yes' if prop['checkbox'] else 'No'
    elif prop_type == 'number':
        return str(prop['number']) if prop['number'] is not None else ''
    elif prop_type == 'date':
        if prop['date']:
            start = prop['date'].get('start')
            end = prop['date'].get('end')
            if end and end != start:
                return f"{start} – {end}"
            return start or ''
        return ''
    elif prop_type == 'people':
        return ', '.join([person.get('name', '') for person in prop['people']])
    elif prop_type == 'status':
        return prop['status']['name'] if prop['status'] else ''
    elif prop_type == 'url':
        return prop['url'] if prop['url'] else ''
    else:
        # Fallback for other types (files, formula, etc.)
        return ''

# %%
def get_notion_db_content(db_id):
    database = notion.databases.retrieve(database_id=db_id)
    rows = notion.databases.query(database_id=db_id)['results']
    # Get column names in display order (title first, then others)
    properties = database['properties']
    columns = []
    # Always put the title property first
    for key, prop in properties.items():
        if prop['type'] == 'title':
            columns.append((key, prop['name']))
    for key, prop in properties.items():
        if prop['type'] != 'title':
            columns.append((key, prop['name']))
    # Build header
    header = '| ' + ' | '.join([col[1] for col in columns]) + ' |'
    # Build separator
    separator = '| ' + ' | '.join(['---' for _ in columns]) + ' |'
    # Build rows
    table_rows = []
    for row in rows:
        props = row['properties']
        row_cells = []
        for key, _ in columns:
            value = extract_property_value(props[key])
            row_cells.append(value)
        table_rows.append('| ' + ' | '.join(row_cells) + ' |')
    # Combine all
    lines = [header, separator] + table_rows
    return '\n'.join(lines)

# %%
blocks = get_children_blocks(pages[0], notion)
for block in blocks:
    print(json.dumps(block, indent=4))
# Out:
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80c6-83b6-cd5023c42220",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-24T16:49:00.000Z",
#     "last_edited_time": "2025-06-24T16:49:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "table_of_contents",
#     "table_of_contents": {
#         "color": "gray"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-811e-9d62-c4c4aa21743b",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-21T14:51:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_2",
#     "heading_2": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Rough Idea",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Rough Idea",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-812d-87ee-e1eaba6e2646",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-21T15:09:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "The idea is to have a central repo to brainstrom on project ideas with the help of an LLM agent. The LLM will be able to see what ideas and projects (complete or incomplete) are disucssed on the notion pages and use them as context for further brain-storming. A script will dump everything available in the notion pages into a vector database every night or whenever the agent is activated. with all that data a knowledge graph is created. which is then used by LLM as context. The agent will also be able to create and update objects in Notion like, pages, databases, etc. according to user prompt.",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "The idea is to have a central repo to brainstrom on project ideas with the help of an LLM agent. The LLM will be able to see what ideas and projects (complete or incomplete) are disucssed on the notion pages and use them as context for further brain-storming. A script will dump everything available in the notion pages into a vector database every night or whenever the agent is activated. with all that data a knowledge graph is created. which is then used by LLM as context. The agent will also be able to create and update objects in Notion like, pages, databases, etc. according to user prompt.",
#                 "href": null
#             }
#         ],
#         "color": "gray"
#     }
# }
# {
#     "object": "block",
#     "id": "2194ba0f-0a3c-8060-b1f6-f9846c3cd9fa",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-21T15:10:00.000Z",
#     "last_edited_time": "2025-06-21T15:10:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Further plan",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Further plan",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "2194ba0f-0a3c-8003-8ee8-e03caa445869",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-21T15:10:00.000Z",
#     "last_edited_time": "2025-06-21T15:52:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "To modify it into something tailored for legal professionals. Add a vector database related to high-court and supreme court casses and central and state statutes.",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "To modify it into something tailored for legal professionals. Add a vector database related to high-court and supreme court casses and central and state statutes.",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-81ae-9607-e8f4d5cea3ca",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-20T14:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_2",
#     "heading_2": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Plan",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Plan",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-815d-b102-f1c1c240669b",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-21T15:56:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Initially the Notion integration will be internal and if everything will be ok I will make a public Notion Integration.",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Initially the Notion integration will be internal and if everything will be ok I will make a public Notion Integration.",
#                 "href": null
#             }
#         ],
#         "color": "gray"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-8134-8ebf-d819c310a62d",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-21T16:03:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "Plan"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-8152-80ed-f6b98c1fc43e",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-20T14:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_2",
#     "heading_2": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Reading list",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Reading list",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-81c8-ae59-f9c636ead743",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-20T14:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Manage the papers, articles and books to read as part of your writeup.",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Manage the papers, articles and books to read as part of your writeup.",
#                 "href": null
#             }
#         ],
#         "color": "gray"
#     }
# }
# {
#     "object": "block",
#     "id": "2184ba0f-0a3c-814d-8f88-caab8dac4032",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-20T14:33:00.000Z",
#     "last_edited_time": "2025-06-23T15:23:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "Reading List"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#     "parent": {
#         "type": "page_id",
#         "page_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b"
#     },
#     "created_time": "2025-06-24T10:32:00.000Z",
#     "last_edited_time": "2025-06-29T14:13:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_2",
#     "heading_2": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "list of all types of blocks that can be created in a notion page",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "list of all types of blocks that can be created in a notion page",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80f6-b28a-f3cdd93cf021",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:33:00.000Z",
#     "last_edited_time": "2025-06-24T10:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "This is simple text",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "This is simple text",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-809c-bfce-c9fbf9ac5ef3",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:33:00.000Z",
#     "last_edited_time": "2025-06-24T10:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_1",
#     "heading_1": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "This is \u2018Heading 1\u2019",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "This is \u2018Heading 1\u2019",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8014-9172-d3d98f3a8fe6",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:33:00.000Z",
#     "last_edited_time": "2025-06-24T10:33:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_2",
#     "heading_2": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "This is \u2018Heading 2\u2019",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "This is \u2018Heading 2\u2019",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80f0-92bb-d67dc88324a1",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:34:00.000Z",
#     "last_edited_time": "2025-06-24T10:34:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "This is \u2018Heading 3\u2019",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "This is \u2018Heading 3\u2019",
#                 "href": null
#             }
#         ],
#         "is_toggleable": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:35:00.000Z",
#     "last_edited_time": "2025-06-24T10:37:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Bulleted list title",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Bulleted list title",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-803b-8181-f30f07bee324",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8"
#     },
#     "created_time": "2025-06-24T10:36:00.000Z",
#     "last_edited_time": "2025-06-24T10:36:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "bulleted_list_item",
#     "bulleted_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 1",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 1",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80a0-9843-dae280be1690",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8"
#     },
#     "created_time": "2025-06-24T10:36:00.000Z",
#     "last_edited_time": "2025-06-24T10:36:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "bulleted_list_item",
#     "bulleted_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 2",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 2",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80fd-971f-d922227b097c",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8"
#     },
#     "created_time": "2025-06-24T10:36:00.000Z",
#     "last_edited_time": "2025-06-24T10:36:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "bulleted_list_item",
#     "bulleted_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 3",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 3",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:37:00.000Z",
#     "last_edited_time": "2025-06-24T10:39:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Numbered list title",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Numbered list title",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-801d-9b67-c3c4b3eb1ebd",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc"
#     },
#     "created_time": "2025-06-24T10:38:00.000Z",
#     "last_edited_time": "2025-06-24T10:38:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "numbered_list_item",
#     "numbered_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 1",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 1",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-803a-8bff-ca46d42abc92",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc"
#     },
#     "created_time": "2025-06-24T10:38:00.000Z",
#     "last_edited_time": "2025-06-24T10:38:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "numbered_list_item",
#     "numbered_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 2",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 2",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8095-9755-f7915ba5e8d6",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc"
#     },
#     "created_time": "2025-06-24T10:38:00.000Z",
#     "last_edited_time": "2025-06-24T10:39:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "numbered_list_item",
#     "numbered_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "point 3 ",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "point 3 ",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:39:00.000Z",
#     "last_edited_time": "2025-06-24T10:40:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "To-Do list title",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "To-Do list title",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80ac-87e6-f51ace585deb",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57"
#     },
#     "created_time": "2025-06-24T10:40:00.000Z",
#     "last_edited_time": "2025-06-24T10:40:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "to_do",
#     "to_do": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Task 1",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Task 1",
#                 "href": null
#             }
#         ],
#         "checked": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8049-967c-f6fcafc54959",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57"
#     },
#     "created_time": "2025-06-24T10:40:00.000Z",
#     "last_edited_time": "2025-06-24T10:40:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "to_do",
#     "to_do": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Task 2",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Task 2",
#                 "href": null
#             }
#         ],
#         "checked": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8020-94ba-e6f46d09d879",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57"
#     },
#     "created_time": "2025-06-24T10:40:00.000Z",
#     "last_edited_time": "2025-06-24T10:40:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "to_do",
#     "to_do": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Task 3",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Task 3",
#                 "href": null
#             }
#         ],
#         "checked": false,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:41:00.000Z",
#     "last_edited_time": "2025-06-24T10:46:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Toggleable list title",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Toggleable list title",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4"
#     },
#     "created_time": "2025-06-24T10:42:00.000Z",
#     "last_edited_time": "2025-06-24T10:45:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "toggle",
#     "toggle": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "item 1",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "item 1",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-800b-9158-dcce5bfbdf6c",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce"
#     },
#     "created_time": "2025-06-24T10:42:00.000Z",
#     "last_edited_time": "2025-06-24T10:44:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Item 1 plain text content\u2026",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Item 1 plain text content\u2026",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8065-81c2-dbbd3bd7abd8",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce"
#     },
#     "created_time": "2025-06-24T10:43:00.000Z",
#     "last_edited_time": "2025-06-24T10:43:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "bulleted_list_item",
#     "bulleted_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "It can have bullets",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "It can have bullets",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8079-8cd3-eb29362dc693",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce"
#     },
#     "created_time": "2025-06-24T10:43:00.000Z",
#     "last_edited_time": "2025-06-24T10:44:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "numbered_list_item",
#     "numbered_list_item": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "it can have numered list",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "it can have numered list",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8081-aaa3-f439ca92f373",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce"
#     },
#     "created_time": "2025-06-24T10:44:00.000Z",
#     "last_edited_time": "2025-06-24T10:44:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "can have everything a notion page can have",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "can have everything a notion page can have",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-803e-87f1-e4e48ca6d428",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4"
#     },
#     "created_time": "2025-06-24T10:45:00.000Z",
#     "last_edited_time": "2025-06-24T10:45:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "toggle",
#     "toggle": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Empty toggle item",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Empty toggle item",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8012-acdc-f4f68c98586d",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4"
#     },
#     "created_time": "2025-06-24T10:46:00.000Z",
#     "last_edited_time": "2025-06-24T10:46:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T10:47:00.000Z",
#     "last_edited_time": "2025-06-24T10:48:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_page",
#     "child_page": {
#         "title": "Embedded page"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80b8-896f-f5df7d31b087",
#     "parent": {
#         "type": "page_id",
#         "page_id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26"
#     },
#     "created_time": "2025-06-24T10:48:00.000Z",
#     "last_edited_time": "2025-06-24T10:48:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "This is an embedded page inside a Notion page.",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "This is an embedded page inside a Notion page.",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80c9-8b6d-ce32aaf12ee2",
#     "parent": {
#         "type": "page_id",
#         "page_id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26"
#     },
#     "created_time": "2025-06-24T10:48:00.000Z",
#     "last_edited_time": "2025-06-24T10:48:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "It has all the functionalities of a normal page\u2026",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "It has all the functionalities of a normal page\u2026",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80df-b5d3-e62ff61192d4",
#     "parent": {
# ...
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "file",
#     "file": {
#         "caption": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "C++ code for quicksort",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "C++ code for quicksort",
#                 "href": null
#             }
#         ],
#         "type": "file",
#         "file": {
#             "url": "https://prod-files-secure.s3.us-west-2.amazonaws.com/e594ba0f-0a3c-8198-a412-0003bf88ca21/18246a72-f450-4fa1-9f51-bb9992ca274e/quicksort.cpp?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466XPZVLI5Y%2F20250705%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20250705T215023Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEQaCXVzLXdlc3QtMiJGMEQCIBXxv22VAleII2%2BHeEYpRMIKGwNF9C2hIKwi%2Bsqt%2Fy30AiBiVtbCYnaSbOontgbRr46qJLE4k6tegzcY%2BiWSgohw7yr%2FAwhNEAAaDDYzNzQyMzE4MzgwNSIMViJ%2BG1K76bQJmvtLKtwDqNogA2loEqBau%2BdFxXCUZW8zWRD0TEmxkK6mj%2BvjQqySJjmJj5fGCS%2FEjyxINAIIclNF4DY6i%2Bfz3iZzuC%2FMvazlm52WlN%2B1tr8Pu1QdkhSL2%2F9uWPXHbX8yTwqAEQ9XmzdnfQmDZLKVLE0WNzKItTL1D9lDiAjrkAv56FiU5jq9EoNrbR3N1UGhwR17jEu5Y699u56%2FU7tzYy2dwwp7ckxA39TzPSz00jQNdnUaZ86wsVADHG4%2B%2F4uQciLw6%2B6NwVYaQ7o1GntnbUl1JRwCMsQfje7Bqn3WnoF7qeZFPfYsUgs87Tijtnf9oGzuYe27jOZQOfVMPj7bhduSHl2lbHgDa674ql5%2FOAKd3Qc5I%2FYZMDziaSdljrArgB%2BfQdnotknSJXIP3zz6s%2BgJwnD8zbZuF%2FQeZS1OJWMPU7tP%2F2sDNFGF0%2Bc0TnokvXTRbpvg%2FxeXKwgVVAQ4vqseVIYjM%2BpigNrR29CRAZsXaYWItbS84uUvCBRdxbNdSPWUwyTGfHAJCqo4WGED23ShjqNe6xqKokfhO25gzO2Gq9gyXw2Raxt%2F8fcB8k6GxjNPSC6KK98Bc5K2GeZJiZZjiG%2FC7TRQ7VLdhfwDgXv8id9xbFK3PhZbFMvJwIMgsxQw3oOmwwY6pgECxBpeTfiGRDutBlBRK%2F072s7Hq3yHevDcVeZgStnF2wTCUnlqSSquhFs5o%2FVp7Pk3cp%2F%2FnUWCGAZvanFAgKjZ8bQxXPnc6e9QK5050HP6RSq3v37uTOhZNlZNQOo83zMsEP6SsCRyBoyrCzOJWFcjJYD%2B9%2F1CGxgkQfswKMhKl0nFP56WTpAdchIp2BGjf1y9EGmy06URMzns2HBbrmE5dSB%2FNFFY&X-Amz-Signature=b642c978bfc616822b78bba927e894a4d2033cee1b6d21f3ce220404cd7a09cf&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject",
#             "expiry_time": "2025-07-05T22:50:23.202Z"
#         },
#         "name": "quicksort.cpp"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80e7-8627-e9bb7ae87b05",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T12:35:00.000Z",
#     "last_edited_time": "2025-06-24T12:43:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "bookmark",
#     "bookmark": {
#         "caption": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Intro to AI agents",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Intro to AI agents",
#                 "href": null
#             }
#         ],
#         "url": "https://medium.com/design-bootcamp/comprehensive-guide-to-ai-agents-in-2025-683651f8d2e6"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-808c-ac50-e889221a0825",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T13:25:00.000Z",
#     "last_edited_time": "2025-06-24T13:51:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "AI Agent Development Courses"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80d6-8450-ea597e230e8a",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T13:35:00.000Z",
#     "last_edited_time": "2025-06-24T13:53:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "Project Ideas"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80b3-acd1-fc68b6c39c71",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T13:54:00.000Z",
#     "last_edited_time": "2025-06-24T14:06:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "AI Agents Gallery"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80d4-b2f9-d319dbf0d71e",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T14:07:00.000Z",
#     "last_edited_time": "2025-06-24T14:13:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "AI Agent Research Tracker"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-806c-b535-f1d2d5fb9543",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T14:57:00.000Z",
#     "last_edited_time": "2025-06-24T16:16:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "Sample Feed"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80ac-90d7-f6e86ee83315",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T16:33:00.000Z",
#     "last_edited_time": "2025-06-29T14:13:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": true,
#     "archived": false,
#     "in_trash": false,
#     "type": "heading_3",
#     "heading_3": {
#         "rich_text": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "Charts and graphs",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "Charts and graphs",
#                 "href": null
#             }
#         ],
#         "is_toggleable": true,
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8048-b1e7-cc5d5bfe21bf",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-80ac-90d7-f6e86ee83315"
#     },
#     "created_time": "2025-06-24T16:34:00.000Z",
#     "last_edited_time": "2025-06-26T06:38:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "child_database",
#     "child_database": {
#         "title": "Data Collection"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-809c-a78f-c8a8ed0592b7",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T16:49:00.000Z",
#     "last_edited_time": "2025-06-24T16:50:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "equation",
#     "equation": {
#         "expression": "e = mc^2"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80fb-8180-c3adc66eb78c",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T17:03:00.000Z",
#     "last_edited_time": "2025-06-24T17:03:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "paragraph",
#     "paragraph": {
#         "rich_text": [
#             {
#                 "type": "equation",
#                 "equation": {
#                     "expression": "pV = nRT"
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "pV = nRT",
#                 "href": null
#             },
#             {
#                 "type": "text",
#                 "text": {
#                     "content": ",  this is the ideal gas law",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": ",  this is the ideal gas law",
#                 "href": null
#             }
#         ],
#         "color": "default"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-80bd-95cb-d4a40da06b3b",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T17:09:00.000Z",
#     "last_edited_time": "2025-06-29T14:08:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "embed",
#     "embed": {
#         "caption": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "PDF embedded using a link",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "PDF embedded using a link",
#                 "href": null
#             }
#         ],
#         "url": "https://arxiv.org/pdf/1706.03762"
#     }
# }
# {
#     "object": "block",
#     "id": "21c4ba0f-0a3c-8006-8b77-c21ae7bc0417",
#     "parent": {
#         "type": "block_id",
#         "block_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce"
#     },
#     "created_time": "2025-06-24T18:06:00.000Z",
#     "last_edited_time": "2025-06-24T18:07:00.000Z",
#     "created_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "last_edited_by": {
#         "object": "user",
#         "id": "218d872b-594c-81ac-8ba0-0002bf19e3d1"
#     },
#     "has_children": false,
#     "archived": false,
#     "in_trash": false,
#     "type": "pdf",
#     "pdf": {
#         "caption": [
#             {
#                 "type": "text",
#                 "text": {
#                     "content": "PDF embedded through an upload",
#                     "link": null
#                 },
#                 "annotations": {
#                     "bold": false,
#                     "italic": false,
#                     "strikethrough": false,
#                     "underline": false,
#                     "code": false,
#                     "color": "default"
#                 },
#                 "plain_text": "PDF embedded through an upload",
#                 "href": null
#             }
#         ],
#         "type": "file",
#         "file": {
#             "url": "https://prod-files-secure.s3.us-west-2.amazonaws.com/e594ba0f-0a3c-8198-a412-0003bf88ca21/595ea197-7227-4646-8dc7-49d2ae30464b/241110406_Uddeshya_Raj.pdf?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIAZI2LB466XPZVLI5Y%2F20250705%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20250705T215023Z&X-Amz-Expires=3600&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEQaCXVzLXdlc3QtMiJGMEQCIBXxv22VAleII2%2BHeEYpRMIKGwNF9C2hIKwi%2Bsqt%2Fy30AiBiVtbCYnaSbOontgbRr46qJLE4k6tegzcY%2BiWSgohw7yr%2FAwhNEAAaDDYzNzQyMzE4MzgwNSIMViJ%2BG1K76bQJmvtLKtwDqNogA2loEqBau%2BdFxXCUZW8zWRD0TEmxkK6mj%2BvjQqySJjmJj5fGCS%2FEjyxINAIIclNF4DY6i%2Bfz3iZzuC%2FMvazlm52WlN%2B1tr8Pu1QdkhSL2%2F9uWPXHbX8yTwqAEQ9XmzdnfQmDZLKVLE0WNzKItTL1D9lDiAjrkAv56FiU5jq9EoNrbR3N1UGhwR17jEu5Y699u56%2FU7tzYy2dwwp7ckxA39TzPSz00jQNdnUaZ86wsVADHG4%2B%2F4uQciLw6%2B6NwVYaQ7o1GntnbUl1JRwCMsQfje7Bqn3WnoF7qeZFPfYsUgs87Tijtnf9oGzuYe27jOZQOfVMPj7bhduSHl2lbHgDa674ql5%2FOAKd3Qc5I%2FYZMDziaSdljrArgB%2BfQdnotknSJXIP3zz6s%2BgJwnD8zbZuF%2FQeZS1OJWMPU7tP%2F2sDNFGF0%2Bc0TnokvXTRbpvg%2FxeXKwgVVAQ4vqseVIYjM%2BpigNrR29CRAZsXaYWItbS84uUvCBRdxbNdSPWUwyTGfHAJCqo4WGED23ShjqNe6xqKokfhO25gzO2Gq9gyXw2Raxt%2F8fcB8k6GxjNPSC6KK98Bc5K2GeZJiZZjiG%2FC7TRQ7VLdhfwDgXv8id9xbFK3PhZbFMvJwIMgsxQw3oOmwwY6pgECxBpeTfiGRDutBlBRK%2F072s7Hq3yHevDcVeZgStnF2wTCUnlqSSquhFs5o%2FVp7Pk3cp%2F%2FnUWCGAZvanFAgKjZ8bQxXPnc6e9QK5050HP6RSq3v37uTOhZNlZNQOo83zMsEP6SsCRyBoyrCzOJWFcjJYD%2B9%2F1CGxgkQfswKMhKl0nFP56WTpAdchIp2BGjf1y9EGmy06URMzns2HBbrmE5dSB%2FNFFY&X-Amz-Signature=6b140d13d10b1e309836a60bdf2c63ba71b1a523a040b8a3e8b170e6e2220004&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject",
#             "expiry_time": "2025-07-05T22:50:23.271Z"
#         }
#     }
# }

# %%
def extract_content(info):
    """
    Given a Notion block ID, extract its content appropriately:
    - If it's a database (type 'child_database' or 'database'), extract as a Markdown table.
    - If it's a table block, extract as a Markdown table.
    - Otherwise, extract as simple content.
    """
    # info = notion.blocks.retrieve(block_id=block_id)
    block_id = info.get('id', '')
    block_type = info['type']

    # Handle Notion databases (inline or top-level)
    if block_type == 'child_database' or block_type == 'database':
        # For both, the block ID is the database ID
        return get_notion_db_content(block_id)

    # Handle simple tables
    elif block_type == 'table':
        return extract_table_as_markdown(block_id)

    # Handle all other block types (paragraph, heading, to_do, etc.)
    else:
        return extract_simple_content(info)

# %%
# for block in blocks:
#     # print(json.dumps(block, indent=4))
#     x = extract_content(block['id'])
#     print(x)

# %%
def extract_children(block_id):
    children = notion.blocks.children.list(block_id=block_id)['results']
    ids = [child['id'] for child in children]
    return ids

# %%
def extract_caption(block):
    block_type = block.get('type')
    content_field = block.get(block_type, {})
    if 'caption' in content_field:
        return ''.join(rt.get('plain_text', '') for rt in content_field['caption'])
    return ''

# %%
def extract_comments(block_id):
    """Extracts all comment texts from a list of Notion comment objects."""
    comments_json = notion.comments.list(block_id=block_id)['results']
    comments_list = []
    for comment in comments_json:
        # Each comment's text is in the 'rich_text' field (list of rich text objects)
        text = ''.join(rt.get('plain_text', '') for rt in comment.get('rich_text', []))
        comments_list.append(text)
    return comments_list

# %%
def get_database_blocks(blocks):
    """
    Returns a list of Notion blocks that are databases (type 'child_database' or 'database').
    """
    db_blocks = []
    for block in blocks:
        if block.get('type') == 'child_database':
            title = block['child_database'].get('title', '')
            if title == '':
                continue
            db_blocks.append(block)
        elif block.get('type') == 'database':
            title = block.get('title', '')
            if title == '':
                continue
            db_blocks.append(block)
    return db_blocks

# Example usage:
# all_blocks = show_children(root_block_id)
database_blocks = get_database_blocks(blocks)
for db in database_blocks:
    db_type = db['type']
    db_id = db['id']
    if db_type == 'child_database':
        title = db['child_database'].get('title', '')
        print(f"Database Block: Title='{title}', ID={db_id}, Type={db_type}")
    elif db_type == 'database':
        title = db.get('title', '')
        print(f"Database Object: Title='{title}', ID={db_id}, Type={db_type}")
# Out:
# Database Block: Title='Plan', ID=2184ba0f-0a3c-8134-8ebf-d819c310a62d, Type=child_database
# Database Block: Title='Reading List', ID=2184ba0f-0a3c-814d-8f88-caab8dac4032, Type=child_database
# Database Block: Title='AI Agent Development Courses', ID=21c4ba0f-0a3c-808c-ac50-e889221a0825, Type=child_database
# Database Block: Title='Project Ideas', ID=21c4ba0f-0a3c-80d6-8450-ea597e230e8a, Type=child_database
# Database Block: Title='AI Agents Gallery', ID=21c4ba0f-0a3c-80b3-acd1-fc68b6c39c71, Type=child_database
# Database Block: Title='AI Agent Research Tracker', ID=21c4ba0f-0a3c-80d4-b2f9-d319dbf0d71e, Type=child_database
# Database Block: Title='Sample Feed', ID=21c4ba0f-0a3c-806c-b535-f1d2d5fb9543, Type=child_database
# Database Block: Title='Data Collection', ID=21c4ba0f-0a3c-8048-b1e7-cc5d5bfe21bf, Type=child_database

# %%
# for idx in range(len(database_blocks)):    
#     db_prop = notion.databases.retrieve(database_id=database_blocks[idx]['id'])
#     db_rows = notion.databases.query(database_id=database_blocks[idx]['id'])['results']
#     print("Database Properties:")
#     print(json.dumps(db_prop, indent=4))
#     print("-"*100)
#     print("Database Rows:")
#     print(json.dumps(db_rows, indent=4))
#     print("="*100, "\n\n")

# %%
# markdown_table = get_notion_db_content("21c4ba0f-0a3c-80b3-acd1-fc68b6c39c71")
# print(markdown_table)

# %%
def make_block_dict(block, context = None, children_map = None):
    parent = block.get('parent', {})
    parent_id = parent.get('page_id', '') or parent.get('block_id', '')
    return {
        'id': block.get('id', ''),
        'parent_id': parent_id,
        'date_created': block.get('created_time', ''),
        'date_updated': block.get('last_edited_time', ''),
        'type': block.get('type', ''),
        'content': extract_content(block),
        'context': context if context else None,
        'children': children_map.get(block.get('id', ''), []) if children_map else [],
        'caption': extract_caption(block),
        'comments': extract_comments(block.get('id', ''))
    }

# %%
def prepare_page(page_id):
    blocks = get_children_blocks(page_id, notion)
    stack = []
    page_data = []
    children_map = {}
    
    for block in blocks:
        parent_id = block.get('parent', {}).get('block_id') or block.get('parent', {}).get('page_id')
        if parent_id:
            children_map.setdefault(parent_id, []).append(block['id'])

    for block in blocks:
        if(block.get('type') == 'unsupported'):
            continue
        if "heading" in block.get('type'):
            heading_level = int(block['type'].split('_')[1])  # e.g., 'heading_1' -> 1
            while stack and stack[-1][0] >= heading_level:
                stack.pop()
            stack.append((heading_level, extract_content(block)+ '\n' + extract_caption(block)))
        else:
            block_id = block.get('id', '')
            if block_id:
                context = ' > '.join([st[1] for st in stack]) or "No heading"
            else:
                context = "No heading"
        block_dict = make_block_dict(block, context=context, children_map=children_map)
        page_data.append(block_dict)
    
    return page_data

# %%
page_data = prepare_page(pages[0])
print(json.dumps(page_data, indent=4))
# Out:
# [
#     {
#         "id": "21c4ba0f-0a3c-80c6-83b6-cd5023c42220",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-24T16:49:00.000Z",
#         "date_updated": "2025-06-24T16:49:00.000Z",
#         "type": "table_of_contents",
#         "content": "",
#         "context": "No heading",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-811e-9d62-c4c4aa21743b",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-21T14:51:00.000Z",
#         "type": "heading_2",
#         "content": "Rough Idea",
#         "context": "No heading",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-812d-87ee-e1eaba6e2646",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-21T15:09:00.000Z",
#         "type": "paragraph",
#         "content": "The idea is to have a central repo to brainstrom on project ideas with the help of an LLM agent. The LLM will be able to see what ideas and projects (complete or incomplete) are disucssed on the notion pages and use them as context for further brain-storming. A script will dump everything available in the notion pages into a vector database every night or whenever the agent is activated. with all that data a knowledge graph is created. which is then used by LLM as context. The agent will also be able to create and update objects in Notion like, pages, databases, etc. according to user prompt.",
#         "context": "Rough Idea\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2194ba0f-0a3c-8060-b1f6-f9846c3cd9fa",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-21T15:10:00.000Z",
#         "date_updated": "2025-06-21T15:10:00.000Z",
#         "type": "heading_3",
#         "content": "Further plan",
#         "context": "Rough Idea\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2194ba0f-0a3c-8003-8ee8-e03caa445869",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-21T15:10:00.000Z",
#         "date_updated": "2025-06-21T15:52:00.000Z",
#         "type": "paragraph",
#         "content": "To modify it into something tailored for legal professionals. Add a vector database related to high-court and supreme court casses and central and state statutes.",
#         "context": "Rough Idea\n > Further plan\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-81ae-9607-e8f4d5cea3ca",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-20T14:33:00.000Z",
#         "type": "heading_2",
#         "content": "Plan",
#         "context": "Rough Idea\n > Further plan\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-815d-b102-f1c1c240669b",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-21T15:56:00.000Z",
#         "type": "paragraph",
#         "content": "Initially the Notion integration will be internal and if everything will be ok I will make a public Notion Integration.",
#         "context": "Plan\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-8134-8ebf-d819c310a62d",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-21T16:03:00.000Z",
#         "type": "child_database",
#         "content": "| Task | Done | Due Date |\n| --- | --- | --- |\n| Write script to update the vectorDB on the server and create Knowledge Graph out of the data | No | 2025-06-21 \u2013 2025-06-29 |\n| Create and deploy vectorDB on an IITK server | No | 2025-06-21 \u2013 2025-06-26 |\n| Code to access Notion objects through API | No | 2025-06-21 \u2013 2025-06-24 |",
#         "context": "Plan\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-8152-80ed-f6b98c1fc43e",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-20T14:33:00.000Z",
#         "type": "heading_2",
#         "content": "Reading list",
#         "context": "Plan\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-81c8-ae59-f9c636ead743",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-20T14:33:00.000Z",
#         "type": "paragraph",
#         "content": "Manage the papers, articles and books to read as part of your writeup.",
#         "context": "Reading list\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "2184ba0f-0a3c-814d-8f88-caab8dac4032",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-20T14:33:00.000Z",
#         "date_updated": "2025-06-23T15:23:00.000Z",
#         "type": "child_database",
#         "content": "| Name | Status |\n| --- | --- |\n| ReAct Agents | To read |\n| MCP server setup | To read |\n| Agentic Function calling | In progress |",
#         "context": "Reading list\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "parent_id": "2184ba0f-0a3c-8034-bc0b-e4c46063376b",
#         "date_created": "2025-06-24T10:32:00.000Z",
#         "date_updated": "2025-07-05T22:21:00.000Z",
#         "type": "heading_1",
#         "content": "list of all types of blocks that can be created in a notion page",
#         "context": "Reading list\n",
#         "children": [
#             "21c4ba0f-0a3c-80f6-b28a-f3cdd93cf021",
#             "21c4ba0f-0a3c-809c-bfce-c9fbf9ac5ef3",
#             "21c4ba0f-0a3c-8014-9172-d3d98f3a8fe6",
#             "21c4ba0f-0a3c-80f0-92bb-d67dc88324a1",
#             "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#             "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#             "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#             "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#             "21c4ba0f-0a3c-809c-8276-fe63e04d4d26",
#             "21c4ba0f-0a3c-80df-b5d3-e62ff61192d4",
#             "21c4ba0f-0a3c-80e3-9dae-f511de823856",
#             "21c4ba0f-0a3c-8028-824e-d9ff88460b05",
#             "21c4ba0f-0a3c-8031-94b7-d21524b1d3b3",
#             "21c4ba0f-0a3c-800f-bbb3-e9bfcbdffbcd",
#             "21c4ba0f-0a3c-802e-adfe-fecdf867e020",
#             "21c4ba0f-0a3c-803c-89ad-ff298f5202de",
#             "21c4ba0f-0a3c-80cd-951c-d28b075e6fea",
#             "21c4ba0f-0a3c-80de-9901-f4c656bccc5a",
#             "21c4ba0f-0a3c-80a3-a146-ef6ea3dbdfd1",
#             "21c4ba0f-0a3c-80e7-8627-e9bb7ae87b05",
#             "21c4ba0f-0a3c-808c-ac50-e889221a0825",
#             "21c4ba0f-0a3c-80d6-8450-ea597e230e8a",
#             "21c4ba0f-0a3c-80b3-acd1-fc68b6c39c71",
#             "21c4ba0f-0a3c-80d4-b2f9-d319dbf0d71e",
#             "21c4ba0f-0a3c-806c-b535-f1d2d5fb9543",
#             "21c4ba0f-0a3c-80ac-90d7-f6e86ee83315",
#             "21c4ba0f-0a3c-809c-a78f-c8a8ed0592b7",
#             "21c4ba0f-0a3c-80fb-8180-c3adc66eb78c",
#             "21c4ba0f-0a3c-80bd-95cb-d4a40da06b3b",
#             "21c4ba0f-0a3c-8006-8b77-c21ae7bc0417"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80f6-b28a-f3cdd93cf021",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:33:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "paragraph",
#         "content": "This is simple text",
#         "context": "list of all types of blocks that can be created in a notion page\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-809c-bfce-c9fbf9ac5ef3",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:33:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_1",
#         "content": "This is \u2018Heading 1\u2019",
#         "context": "list of all types of blocks that can be created in a notion page\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8014-9172-d3d98f3a8fe6",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:33:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_2",
#         "content": "This is \u2018Heading 2\u2019",
#         "context": "list of all types of blocks that can be created in a notion page\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80f0-92bb-d67dc88324a1",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:34:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "This is \u2018Heading 3\u2019",
#         "context": "list of all types of blocks that can be created in a notion page\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:35:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "Bulleted list title",
#         "context": "list of all types of blocks that can be created in a notion page\n",
#         "children": [
#             "21c4ba0f-0a3c-803b-8181-f30f07bee324",
#             "21c4ba0f-0a3c-80a0-9843-dae280be1690",
#             "21c4ba0f-0a3c-80fd-971f-d922227b097c"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-803b-8181-f30f07bee324",
#         "parent_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#         "date_created": "2025-06-24T10:36:00.000Z",
#         "date_updated": "2025-06-24T10:36:00.000Z",
#         "type": "bulleted_list_item",
#         "content": "point 1",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Bulleted list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80a0-9843-dae280be1690",
#         "parent_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#         "date_created": "2025-06-24T10:36:00.000Z",
#         "date_updated": "2025-06-24T10:36:00.000Z",
#         "type": "bulleted_list_item",
#         "content": "point 2",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Bulleted list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80fd-971f-d922227b097c",
#         "parent_id": "21c4ba0f-0a3c-80a8-8151-f68dc167f9d8",
#         "date_created": "2025-06-24T10:36:00.000Z",
#         "date_updated": "2025-06-24T10:36:00.000Z",
#         "type": "bulleted_list_item",
#         "content": "point 3",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Bulleted list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:37:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "Numbered list title",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Bulleted list title\n",
#         "children": [
#             "21c4ba0f-0a3c-801d-9b67-c3c4b3eb1ebd",
#             "21c4ba0f-0a3c-803a-8bff-ca46d42abc92",
#             "21c4ba0f-0a3c-8095-9755-f7915ba5e8d6"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-801d-9b67-c3c4b3eb1ebd",
#         "parent_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#         "date_created": "2025-06-24T10:38:00.000Z",
#         "date_updated": "2025-06-24T10:38:00.000Z",
#         "type": "numbered_list_item",
#         "content": "point 1",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Numbered list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-803a-8bff-ca46d42abc92",
#         "parent_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#         "date_created": "2025-06-24T10:38:00.000Z",
#         "date_updated": "2025-06-24T10:38:00.000Z",
#         "type": "numbered_list_item",
#         "content": "point 2",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Numbered list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8095-9755-f7915ba5e8d6",
#         "parent_id": "21c4ba0f-0a3c-80b8-8b49-c94cb06526fc",
#         "date_created": "2025-06-24T10:38:00.000Z",
#         "date_updated": "2025-06-24T10:39:00.000Z",
#         "type": "numbered_list_item",
#         "content": "point 3 ",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Numbered list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:39:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "To-Do list title",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Numbered list title\n",
#         "children": [
#             "21c4ba0f-0a3c-80ac-87e6-f51ace585deb",
#             "21c4ba0f-0a3c-8049-967c-f6fcafc54959",
#             "21c4ba0f-0a3c-8020-94ba-e6f46d09d879"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80ac-87e6-f51ace585deb",
#         "parent_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#         "date_created": "2025-06-24T10:40:00.000Z",
#         "date_updated": "2025-06-24T10:40:00.000Z",
#         "type": "to_do",
#         "content": "Task 1 (done)",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > To-Do list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8049-967c-f6fcafc54959",
#         "parent_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#         "date_created": "2025-06-24T10:40:00.000Z",
#         "date_updated": "2025-06-24T10:40:00.000Z",
#         "type": "to_do",
#         "content": "Task 2 (done)",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > To-Do list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8020-94ba-e6f46d09d879",
#         "parent_id": "21c4ba0f-0a3c-8083-98fa-d64791a89e57",
#         "date_created": "2025-06-24T10:40:00.000Z",
#         "date_updated": "2025-06-24T10:40:00.000Z",
#         "type": "to_do",
#         "content": "Task 3",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > To-Do list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:41:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "Toggleable list title",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > To-Do list title\n",
#         "children": [
#             "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#             "21c4ba0f-0a3c-803e-87f1-e4e48ca6d428",
#             "21c4ba0f-0a3c-8012-acdc-f4f68c98586d"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#         "parent_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#         "date_created": "2025-06-24T10:42:00.000Z",
#         "date_updated": "2025-06-24T10:45:00.000Z",
#         "type": "toggle",
#         "content": "item 1",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [
#             "21c4ba0f-0a3c-800b-9158-dcce5bfbdf6c",
#             "21c4ba0f-0a3c-8065-81c2-dbbd3bd7abd8",
#             "21c4ba0f-0a3c-8079-8cd3-eb29362dc693",
#             "21c4ba0f-0a3c-8081-aaa3-f439ca92f373"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-800b-9158-dcce5bfbdf6c",
#         "parent_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#         "date_created": "2025-06-24T10:42:00.000Z",
#         "date_updated": "2025-06-24T10:44:00.000Z",
#         "type": "paragraph",
#         "content": "Item 1 plain text content\u2026",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8065-81c2-dbbd3bd7abd8",
#         "parent_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#         "date_created": "2025-06-24T10:43:00.000Z",
#         "date_updated": "2025-06-24T10:43:00.000Z",
#         "type": "bulleted_list_item",
#         "content": "It can have bullets",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8079-8cd3-eb29362dc693",
#         "parent_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#         "date_created": "2025-06-24T10:43:00.000Z",
#         "date_updated": "2025-06-24T10:44:00.000Z",
#         "type": "numbered_list_item",
#         "content": "it can have numered list",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8081-aaa3-f439ca92f373",
#         "parent_id": "21c4ba0f-0a3c-8085-bcc9-de9a5cadfcce",
#         "date_created": "2025-06-24T10:44:00.000Z",
#         "date_updated": "2025-06-24T10:44:00.000Z",
#         "type": "paragraph",
#         "content": "can have everything a notion page can have",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-803e-87f1-e4e48ca6d428",
#         "parent_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#         "date_created": "2025-06-24T10:45:00.000Z",
#         "date_updated": "2025-06-24T10:45:00.000Z",
#         "type": "toggle",
#         "content": "Empty toggle item",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8012-acdc-f4f68c98586d",
#         "parent_id": "21c4ba0f-0a3c-8037-8024-e0016b0a35a4",
#         "date_created": "2025-06-24T10:46:00.000Z",
#         "date_updated": "2025-06-24T10:46:00.000Z",
#         "type": "paragraph",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:47:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_page",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [
#             "21c4ba0f-0a3c-80b8-896f-f5df7d31b087",
#             "21c4ba0f-0a3c-80c9-8b6d-ce32aaf12ee2"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80b8-896f-f5df7d31b087",
#         "parent_id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26",
#         "date_created": "2025-06-24T10:48:00.000Z",
#         "date_updated": "2025-06-24T10:48:00.000Z",
#         "type": "paragraph",
#         "content": "This is an embedded page inside a Notion page.",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80c9-8b6d-ce32aaf12ee2",
#         "parent_id": "21c4ba0f-0a3c-809c-8276-fe63e04d4d26",
#         "date_created": "2025-06-24T10:48:00.000Z",
#         "date_updated": "2025-06-24T10:48:00.000Z",
#         "type": "paragraph",
#         "content": "It has all the functionalities of a normal page\u2026",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80df-b5d3-e62ff61192d4",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:49:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "callout",
#         "content": "This is a callout sample to highlight something",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80e3-9dae-f511de823856",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:51:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "quote",
#         "content": "\u201cI am definitely going to complete this project this time\u201d -Uddeshya Raj (2025)",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8028-824e-d9ff88460b05",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:54:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "Truth Table for XOR gate (simple Table)",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Toggleable list title\n",
#         "children": [
#             "21c4ba0f-0a3c-8061-a25c-ed6a33c0cd29"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8061-a25c-ed6a33c0cd29",
#         "parent_id": "21c4ba0f-0a3c-8028-824e-d9ff88460b05",
#         "date_created": "2025-06-24T10:54:00.000Z",
#         "date_updated": "2025-06-24T10:56:00.000Z",
#         "type": "table",
#         "content": "| A xor B | True                                | False |\n|---------|-------------------------------------|-------|\n| True    | False (plus extra text for testing) | True  |\n| False   | True                                | False |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [
#             "21c4ba0f-0a3c-802a-91ba-d5be82fe06b9",
#             "21c4ba0f-0a3c-8082-bff4-c9170d06f503",
#             "21c4ba0f-0a3c-806f-a516-f84a9c3e9aa1"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-802a-91ba-d5be82fe06b9",
#         "parent_id": "21c4ba0f-0a3c-8061-a25c-ed6a33c0cd29",
#         "date_created": "2025-06-24T10:54:00.000Z",
#         "date_updated": "2025-06-24T10:59:00.000Z",
#         "type": "table_row",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8082-bff4-c9170d06f503",
#         "parent_id": "21c4ba0f-0a3c-8061-a25c-ed6a33c0cd29",
#         "date_created": "2025-06-24T10:54:00.000Z",
#         "date_updated": "2025-06-25T10:43:00.000Z",
#         "type": "table_row",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-806f-a516-f84a9c3e9aa1",
#         "parent_id": "21c4ba0f-0a3c-8061-a25c-ed6a33c0cd29",
#         "date_created": "2025-06-24T10:54:00.000Z",
#         "date_updated": "2025-06-24T10:59:00.000Z",
#         "type": "table_row",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8031-94b7-d21524b1d3b3",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T10:59:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "divider",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-800f-bbb3-e9bfcbdffbcd",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T11:00:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "link_to_page",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-802e-adfe-fecdf867e020",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T11:03:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "image",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "Mera photo",
#         "comments": [
#             "Oh my god, kya handsome banda hai. Isse to bahut maza aayega. \ud83e\udd23 @Uddeshya Raj "
#         ]
#     },
#     {
#         "id": "21c4ba0f-0a3c-803c-89ad-ff298f5202de",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T11:11:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "video",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "sample video",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80cd-951c-d28b075e6fea",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T11:18:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "audio",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80de-9901-f4c656bccc5a",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T12:28:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "code",
#         "content": "#include <iostream>\n#include <vector>\n#include <iomanip> // For std::setw to format output\n\nint main() {\n    int height;\n    std::cout << \"Enter the height of Pascal's Triangle: \";\n    std::cin >> height;\n\n    // Create a 2D vector to store the triangle\n    std::vector<std::vector<int>> pascalTriangle(height);\n\n    for (int i = 0; i < height; ++i) {\n        // Resize each row to accommodate 'i + 1' elements\n        pascalTriangle[i].resize(i + 1);\n\n        // The first and last elements of each row are always 1\n        pascalTriangle[i][0] = 1;\n        pascalTriangle[i][i] = 1;\n\n        // Calculate the middle elements of the current row\n        for (int j = 1; j < i; ++j) {\n            pascalTriangle[i][j] = pascalTriangle[i - 1][j - 1] + pascalTriangle[i - 1][j];\n        }\n    }\n\n    // Print the Pascal's Triangle\n    for (int i = 0; i < height; ++i) {\n        // Add leading spaces for proper alignment\n        for (int space = 0; space < (height - i - 1) * 2; ++space) {\n            std::cout << \" \";\n        }\n\n        for (int j = 0; j <= i; ++j) {\n            std::cout << std::setw(4) << pascalTriangle[i][j]; // Use setw for consistent spacing\n        }\n        std::cout << std::endl;\n    }\n\n    return 0;\n}",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "Code to print pascal\u2019s triangle of a given height",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80a3-a146-ef6ea3dbdfd1",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T12:32:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "file",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "C++ code for quicksort",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80e7-8627-e9bb7ae87b05",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T12:35:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "bookmark",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "Intro to AI agents",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-808c-ac50-e889221a0825",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T13:25:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_database",
#         "content": "| Course Name | Platform/Organization | Duration | Difficulty Level | Rating | Price |\n| --- | --- | --- | --- | --- | --- |\n| Building AI Chatbots and Agents | edX | 5 weeks | Beginner | 4.3 | Free (certificate: $149) |\n| AI Agents: Building with Langchain & LLMs | Coursera | 6 weeks | Intermediate | 4.6 | $79 or subscription |\n| Autonomous Agents & Agentic Workflows | DeepLearning.AI | 4 weeks | Advanced | 4.8 | $49 |\n| Building AI Agents with OpenAI's Assistant API | Udemy | 12 hours | Intermediate | 4.5 | $89.99 |\n| Langchain & Vector Databases in Production | Activeloop | 8 hours | Intermediate | 4.7 | $39.99 |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80d6-8450-ea597e230e8a",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T13:35:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_database",
#         "content": "| Name | Priority | Assign | Status |\n| --- | --- | --- | --- |\n| IRCTC AI agent | low | Uddeshya Raj | Not started |\n| IBPS upgrade | medium | Uddeshya Raj | Not started |\n| ILTUR paper submission for bail prediction task (HLDC data) | high | Uddeshya Raj | Not started |\n| Notion Agent | medium | Uddeshya Raj | In progress |\n| IBPS for Hackathon |  | Uddeshya Raj | Done |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80b3-acd1-fc68b6c39c71",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T13:54:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_database",
#         "content": "| Agent Name | Created Date | Developer | Description | Use Case | Type | Rating | Capabilities | Platform |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| PixelMaster | 2025-04-30 | Creative AI Labs | PixelMaster generates high-quality images from text descriptions. It excels at creating realistic scenes, conceptual art, and product visualizations based on detailed prompts. | Digital art creation, marketing materials, and concept visualization | Image Generator | 4.8 | Image Recognition, Text Generation | Web |\n| DataViz Pro | 2025-03-15 | AnalyticsCorp | DataViz Pro automates complex data analysis and visualization tasks. It can process large datasets, identify patterns, and create interactive dashboards with minimal user input. | Business intelligence and data-driven decision making | Data Analysis | 4.3 | Data Analysis, Text Generation, Content Summarization | Web |\n| Aria Assistant | 2025-05-23 | TechMind Solutions | Aria is a versatile AI assistant designed to help with productivity tasks, writing assistance, and code generation. It features advanced natural language understanding and can adapt to user preferences over time. | Professional productivity and creative assistance for knowledge workers | Assistant | 4.7 | Text Generation, Code Generation, Content Summarization | Cross-platform |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80d4-b2f9-d319dbf0d71e",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T14:07:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_database",
#         "content": "| Topic/Paper Title | Publication/Source | Notes | Year | Priority | Authors | Type | Date Completed | Key Topics | Relevance Score | Citation Count | Completed |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| Embodied AI: Connecting Language Models to Robotic Control | ICML Workshop | Tutorial exploring the integration of large language models with physical robotic systems for real-world interaction. | 2025 | Low | Rishi Bommasani, Peter Chen, Yi Wu | Tutorial | 2025-06-28 | Embodied AI, Robotics, LLMs | Somewhat Relevant | 98 | No |\n| Multi-Agent Collaboration: Principles and Applications | MIT Press | Comprehensive overview of multi-agent systems with excellent examples of collaborative problem-solving frameworks. | 2024 | Medium | Sarah Johnson, Michael Chen | Book | 2025-06-21 | Multi-Agent Systems, Planning, Decision Making | Very Relevant | 342 | Yes |\n| Language Models can Solve Computer Tasks | arXiv preprint | This paper demonstrates how LLMs can use tools to solve computer tasks such as information finding, calendar management, and email processing. | 2023 | High | Wenlong Zhao, Yuhao Wan, Hao Liu, Shihao Liang, et al. | Research Paper | 2025-06-26 | LLMs, Tool Use, Decision Making | Very Relevant | 1284 | No |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-806c-b535-f1d2d5fb9543",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T14:57:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "child_database",
#         "content": "| Name |\n| --- |\n| Breaking: Revolutionary AI Agent \"MindWeaver\" Decodes Human Creativity |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80ac-90d7-f6e86ee83315",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T16:33:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "heading_3",
#         "content": "Charts and graphs",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Truth Table for XOR gate (simple Table)\n",
#         "children": [
#             "21c4ba0f-0a3c-8048-b1e7-cc5d5bfe21bf"
#         ],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8048-b1e7-cc5d5bfe21bf",
#         "parent_id": "21c4ba0f-0a3c-80ac-90d7-f6e86ee83315",
#         "date_created": "2025-06-24T16:34:00.000Z",
#         "date_updated": "2025-06-26T06:38:00.000Z",
#         "type": "child_database",
#         "content": "| Name | Source | Value | Status | Tags | Notes | Date Recorded | Category |\n| --- | --- | --- | --- | --- | --- | --- | --- |\n| Customer Acquisition Cost |  | 142.85 | Under Review | Important, To Review, Work | Average cost to acquire a new customer in June. Shows 12% reduction from previous month. | 2025-06-21 | Sales |\n| Monthly Server Uptime |  | 99.97 | Verified | Work, Reference | Percentage of server uptime for the month of June. Exceeds our SLA requirements. | 2025-06-23 | IT |\n| Q2 Marketing Campaign ROI |  | 4.37 | Verified | Important, Work, Project | Analysis of return on investment for our Q2 digital marketing campaign showing better than expected results. | 2025-06-20 | Marketing |",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Charts and graphs\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-809c-a78f-c8a8ed0592b7",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T16:49:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "equation",
#         "content": "e = mc^2",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Charts and graphs\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80fb-8180-c3adc66eb78c",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T17:03:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "paragraph",
#         "content": "pV = nRT,  this is the ideal gas law",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Charts and graphs\n",
#         "children": [],
#         "caption": "",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-80bd-95cb-d4a40da06b3b",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T17:09:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "embed",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Charts and graphs\n",
#         "children": [],
#         "caption": "PDF embedded using a link",
#         "comments": []
#     },
#     {
#         "id": "21c4ba0f-0a3c-8006-8b77-c21ae7bc0417",
#         "parent_id": "21c4ba0f-0a3c-8067-9706-e9d4b8b40dce",
#         "date_created": "2025-06-24T18:06:00.000Z",
#         "date_updated": "2025-07-05T22:20:00.000Z",
#         "type": "pdf",
#         "content": "",
#         "context": "This is \u2018Heading 1\u2019\n > This is \u2018Heading 2\u2019\n > Charts and graphs\n",
#         "children": [],
#         "caption": "PDF embedded through an upload",
#         "comments": []
#     }
# ]
